# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import sys
sys.path.append('../')

from sklearn.model_selection import train_test_split

import dipy
from dipy.segment.tissue import TissueClassifierHMRF

# %%
from getdata import *
df_o = get_csvdata()
df_a = get_csvdata_ADNI()

# %%
path = df_a['ID'].iloc[0]

# %%
#img = get_slices_ADNI_new([path], dim=2, m=100, normalize=False)
img = get_3D_data_ADNI([path], normalize=False)

# %%
plt.imshow(img[0,:,:,95])

# %%
hmrf = TissueClassifierHMRF()
initial_segmentation, final_segmentation, PVE = hmrf.classify(img[0], 4, 0.1)
# Out:
# >> Iteration: 0
# >> Iteration: 1
# >> Iteration: 2
# >> Iteration: 3
# >> Iteration: 4
# >> Iteration: 5
# >> Iteration: 6
# >> Iteration: 7
# >> Iteration: 8
# >> Iteration: 9
# >> Iteration: 10
# >> Iteration: 11
# >> Iteration: 12
# >> Iteration: 13
# >> Iteration: 14
# >> Iteration: 15
# >> Iteration: 16
# >> Iteration: 17
# >> Iteration: 18
# >> Iteration: 19
# >> Iteration: 20
# >> Iteration: 21
# >> Iteration: 22
# >> Iteration: 23
# >> Iteration: 24
# >> Iteration: 25
# >> Iteration: 26
# >> Iteration: 27
# >> Iteration: 28
# >> Iteration: 29
# >> Iteration: 30
# >> Iteration: 31
# >> Iteration: 32
# >> Iteration: 33
# >> Iteration: 34
# >> Iteration: 35
# >> Iteration: 36
# >> Iteration: 37
# >> Iteration: 38
# >> Iteration: 39
# >> Iteration: 40
# >> Iteration: 41
# >> Iteration: 42
# >> Iteration: 43
# >> Iteration: 44
# >> Iteration: 45
# >> Iteration: 46
# >> Iteration: 47
# >> Iteration: 48
# >> Iteration: 49
# >> Iteration: 50
# >> Iteration: 51
# >> Iteration: 52
# ...

# %%
plt.imshow(final_segmentation[:,:,100])

# %%
import shutil 
df = pd.read_csv('../data/oasis_cross-sectional.csv')
IDs = df['ID']

for path in IDs:
    path1 = '../data/Oasis_Data/' + path + '/PROCESSED/MPRAGE/T88_111/'
    for path2 in os.listdir(path1):
        if path2.endswith('masked_gfc.img'):
            shutil.copy(path1+path2, '../data/imgs/'+path+'.img')

# %%
import shutil 
df = pd.read_csv('../data/oasis_cross-sectional.csv')
IDs = df['ID']

for path in IDs:
    path1 = '../data/Oasis_Data/' + path + '/PROCESSED/MPRAGE/T88_111/'
    for path2 in os.listdir(path1):
        if path2.endswith('masked_gfc.hdr'):
            shutil.copy(path1+path2, '../data/imgs/'+path+'.hdr')

# %%
import nibabel as nib

nib.load('../data/imgs/'+path+'.img')

# %%
df_a
# Out:
#      Image Data ID          ID Group Sex  Age  Visit Modality  \
# 2884       I167590  002_S_0295    CN   M   85      1      MRI
# 2882       I252117  002_S_0413    CN   F   76      1      MRI
# 2881       I252119  002_S_0559    CN   M   79      1      MRI
# 2874       I173018  002_S_0619    AD   M   78      1      MRI
# 2871       I172953  002_S_0685    CN   F   90      1      MRI
# ...            ...         ...   ...  ..  ...    ...      ...
# 26         I185266  941_S_1194    CN   M   85      1      MRI
# 20         I185280  941_S_1195    CN   M   77      1      MRI
# 16         I173860  941_S_1197    CN   F   82      1      MRI
# 14         I173864  941_S_1202    CN   M   78      1      MRI
# 10         I185313  941_S_1203    CN   M   83      1      MRI
#
#                                           Description            Type  \
# 2884  FreeSurfer Cross-Sectional Processing brainmask  Post-processed
# 2882  FreeSurfer Cross-Sectional Processing brainmask  Post-processed
# ...

# %%
df = pd.read_csv("../data/ADNI_Freesurfer/FreeSurfer_8_23_2022.csv")
df
# Out:
#      Image Data ID     Subject Group Sex  Age  Visit Modality  \
# 0          I185317  941_S_1363   MCI   F   70      1      MRI
# 1          I185316  941_S_1363   MCI   F   70      1      MRI
# 2          I222554  941_S_1311   MCI   M   69      1      MRI
# 3          I173269  941_S_1311   MCI   M   69      1      MRI
# 4          I222553  941_S_1311   MCI   M   69      1      MRI
# ...            ...         ...   ...  ..  ...    ...      ...
# 2881       I252119  002_S_0559    CN   M   79      1      MRI
# 2882       I252117  002_S_0413    CN   F   76      1      MRI
# 2883       I252116  002_S_0413    CN   F   76      1      MRI
# 2884       I167590  002_S_0295    CN   M   85      1      MRI
# 2885       I167591  002_S_0295    CN   M   85      1      MRI
#
#                                            Description            Type  \
# 0      FreeSurfer Cross-Sectional Processing brainmask  Post-processed
# 1     FreeSurfer Cross-Sectional Processing aparc+aseg  Post-processed
# ...

# %%
df.groupby('Visit').count()
# Out:
#        Image Data ID  Subject  Group   Sex   Age  Modality  Description  Type  \
# Visit
# 1               2886     2886   2886  2886  2886      2886         2886  2886
#
#        Acq Date  Format  Downloaded
# Visit
# 1          2886    2886        2886

# %%
import nibabel as nib
img = nib.load('../data/ADNI_Freesurfer/ADNI/002_S_0295/FreeSurfer_Cross-Sectional_Processing_aparc+aseg/2006-04-18_08_20_30.0/I167591/aparc+aseg.mgz')

# %%
img = img.get_fdata()

# %%
plt.imshow(img[:,:,90])
