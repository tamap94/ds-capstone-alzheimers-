# %%
pip install SimpleITK
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.2/30.2 MB 1.5 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import SimpleITK as sitk
import matplotlib.pyplot as plt
#import gui

# %%
import numpy as np
import nibabel as nib

# %%
img2 = nib.load("ADNI_002_S_0295_VOLUME_FreeSurfer_Cross-Sectional_Processing_Br_20100310173858891.brainmask.nii")
img2 = img2.get_fdata()
img2= np.rot90(img2, k=2, axes=(0,2))
plt.imshow(img2[:,:,100,0])

# %%
img3 = nib.load("002_S_0295-brainmask.mgz")
img3 = img3.get_fdata()
plt.imshow(img3[:,100,:])
