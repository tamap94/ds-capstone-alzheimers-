# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import sys
sys.path.append('../')

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, recall_score, precision_score, precision_recall_curve

import tensorflow as tf
import keras 

from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, InputLayer, Flatten, Conv2D, MaxPooling2D

np.random.seed(42)
tf.random.set_seed(42)

from preprocessing.getdata import *

# %%
df_a = get_csvdata_ADNI()
df_o= get_csvdata(drop_young=True, drop_contradictions=False)

for ID in ['013_S_1275', '099_S_0533', '123_S_0050', '131_S_0457', '137_S_0796']:
    df_a = df_a[df_a['ID']!=ID]

df_a = df_a[df_a['Group']!='MCI']
y_a = (df_a['Group']!='CN').astype(int)
df_a_train, df_a_test, y_a_train, y_a_test = train_test_split(df_a['ID'], y_a, stratify=y_a, random_state=42)

y_o = df_o['CDR']
df_o_train, df_o_test, y_o_train, y_o_test = train_test_split(df_o['ID'], y_o, stratify=y_o, random_state=42)

# %%
N=5
d=1
mdict = {0: 95, 1: 110, 2: 90}

y_o_train = y_o_train.repeat(1+2*N)
y_a_train = y_a_train.repeat(1+2*N)

for dim in range(3):
  m = mdict[dim]
  X_train_o = get_slices(df_o_train, dim=dim, m=m, N=N, d=d)
  X_train_a = get_slices_ADNI2(df_a_train, dim=dim, m=m, N=N, d=d)

  X_test_o = get_slices(df_o_test, dim=dim, m=m)
  X_test_a = get_slices_ADNI2(df_a_test, dim=dim, m=m)

  X_train = np.concatenate((X_train_o, X_train_a), axis=0)
  X_test = np.concatenate((X_test_o, X_test_a), axis=0)

  y_train = np.concatenate((y_o_train, y_a_train))
  y_test = np.concatenate((y_o_test, y_a_test))

  X_train = np.repeat(X_train[..., np.newaxis], 3, -1)
  X_test = np.repeat(X_test[..., np.newaxis], 3, -1)


  HEIGHT = X_train.shape[1]
  WIDTH = X_train.shape[2]

  INPUT_SHAPE = (HEIGHT, WIDTH, 3)
  b_model = tf.keras.applications.VGG16(include_top=False, weights='imagenet', input_shape=INPUT_SHAPE)

  model = Sequential()
  model.add(InputLayer(input_shape=INPUT_SHAPE))
  model.add(b_model)
  model.add(Flatten())
  model.add(Dense(512, activation='relu', kernel_regularizer=keras.regularizers.l2(l=0.1)))
  model.add(Dropout(0.3))
  model.add(Dense(512, activation='relu', kernel_regularizer=keras.regularizers.l2(l=0.1)))
  model.add(Dense(1, activation="sigmoid"))

  # Defining optimizer and learning rate
  lr_schedule = tf.keras.optimizers.schedules.InverseTimeDecay(
      0.00001,
      decay_steps=10000,
      decay_rate=1,
      staircase=False)
  optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule, name='Adam')
  model.compile(optimizer = optimizer, loss = 'binary_crossentropy', metrics = ['accuracy'])

  with tf.device('/device:GPU:0'):
    model_history = model.fit(X_train, y_train, epochs=20, shuffle=True, validation_data=(X_test, y_test))
  
  model.save('axis'+str(dim))
# Out:
# Epoch 1/20
# 160/160 [==============================] - 56s 310ms/step - loss: 138.7615 - accuracy: 0.6311 - val_loss: 127.8482 - val_accuracy: 0.7115
# Epoch 2/20
# 160/160 [==============================] - 45s 278ms/step - loss: 118.4541 - accuracy: 0.8023 - val_loss: 109.9123 - val_accuracy: 0.7179
# Epoch 3/20
# 160/160 [==============================] - 46s 285ms/step - loss: 101.9877 - accuracy: 0.8848 - val_loss: 95.3348 - val_accuracy: 0.7179
# Epoch 4/20
# 160/160 [==============================] - 46s 289ms/step - loss: 88.4418 - accuracy: 0.9372 - val_loss: 83.1983 - val_accuracy: 0.6987
# Epoch 5/20
# 160/160 [==============================] - 47s 292ms/step - loss: 77.1696 - accuracy: 0.9748 - val_loss: 73.1832 - val_accuracy: 0.7179
# Epoch 6/20
# 160/160 [==============================] - 47s 292ms/step - loss: 67.7229 - accuracy: 0.9855 - val_loss: 64.6786 - val_accuracy: 0.7308
# Epoch 7/20
# 160/160 [==============================] - 47s 293ms/step - loss: 59.7276 - accuracy: 0.9949 - val_loss: 57.4666 - val_accuracy: 0.7179
# Epoch 8/20
# 160/160 [==============================] - 47s 294ms/step - loss: 52.9421 - accuracy: 0.9957 - val_loss: 51.4155 - val_accuracy: 0.7115
# Epoch 9/20
# 160/160 [==============================] - 47s 295ms/step - loss: 47.1611 - accuracy: 0.9965 - val_loss: 46.1040 - val_accuracy: 0.7051
# Epoch 10/20
# 160/160 [==============================] - 47s 295ms/step - loss: 42.2083 - accuracy: 0.9996 - val_loss: 41.6635 - val_accuracy: 0.7179
# Epoch 11/20
# 160/160 [==============================] - 47s 295ms/step - loss: 37.9727 - accuracy: 0.9977 - val_loss: 37.7258 - val_accuracy: 0.7308
# Epoch 12/20
# 160/160 [==============================] - 47s 295ms/step - loss: 34.3126 - accuracy: 1.0000 - val_loss: 34.3850 - val_accuracy: 0.6987
# Epoch 13/20
# 160/160 [==============================] - 47s 296ms/step - loss: 31.1578 - accuracy: 0.9990 - val_loss: 31.3561 - val_accuracy: 0.6987
# Epoch 14/20
# 160/160 [==============================] - 47s 295ms/step - loss: 28.4242 - accuracy: 0.9967 - val_loss: 28.6172 - val_accuracy: 0.7051
# Epoch 15/20
# 160/160 [==============================] - 47s 296ms/step - loss: 26.0418 - accuracy: 0.9990 - val_loss: 26.6282 - val_accuracy: 0.7244
# Epoch 16/20
# 160/160 [==============================] - 47s 296ms/step - loss: 23.9703 - accuracy: 0.9965 - val_loss: 24.7018 - val_accuracy: 0.7308
# Epoch 17/20
# 160/160 [==============================] - 47s 296ms/step - loss: 22.1297 - accuracy: 1.0000 - val_loss: 23.0305 - val_accuracy: 0.7179
# Epoch 18/20
# 160/160 [==============================] - 47s 296ms/step - loss: 20.4979 - accuracy: 1.0000 - val_loss: 21.4881 - val_accuracy: 0.7051
# Epoch 19/20
# 160/160 [==============================] - 47s 296ms/step - loss: 19.0345 - accuracy: 1.0000 - val_loss: 20.1039 - val_accuracy: 0.7244
# Epoch 20/20
# 160/160 [==============================] - 47s 296ms/step - loss: 17.7138 - accuracy: 1.0000 - val_loss: 18.8206 - val_accuracy: 0.7372
# Epoch 1/20
# 160/160 [==============================] - 64s 363ms/step - loss: 138.6515 - accuracy: 0.6598 - val_loss: 127.3268 - val_accuracy: 0.6090
# Epoch 2/20
# 160/160 [==============================] - 53s 331ms/step - loss: 117.3927 - accuracy: 0.7806 - val_loss: 108.4167 - val_accuracy: 0.6410
# Epoch 3/20
# 160/160 [==============================] - 54s 340ms/step - loss: 100.2811 - accuracy: 0.8665 - val_loss: 93.3445 - val_accuracy: 0.6410
# Epoch 4/20
# 160/160 [==============================] - 55s 347ms/step - loss: 86.4242 - accuracy: 0.9351 - val_loss: 81.1720 - val_accuracy: 0.6474
# Epoch 5/20
# 160/160 [==============================] - 56s 347ms/step - loss: 75.0682 - accuracy: 0.9758 - val_loss: 71.1695 - val_accuracy: 0.6474
# Epoch 6/20
# 160/160 [==============================] - 56s 348ms/step - loss: 65.6786 - accuracy: 0.9875 - val_loss: 62.7044 - val_accuracy: 0.6538
# Epoch 7/20
# 160/160 [==============================] - 56s 349ms/step - loss: 57.8358 - accuracy: 0.9934 - val_loss: 55.7228 - val_accuracy: 0.6667
# Epoch 8/20
# 160/160 [==============================] - 56s 350ms/step - loss: 51.2353 - accuracy: 0.9988 - val_loss: 50.0876 - val_accuracy: 0.6218
# Epoch 9/20
# 160/160 [==============================] - 56s 351ms/step - loss: 45.6690 - accuracy: 0.9953 - val_loss: 44.5089 - val_accuracy: 0.6410
# Epoch 10/20
# 160/160 [==============================] - 56s 351ms/step - loss: 40.9448 - accuracy: 0.9975 - val_loss: 40.3324 - val_accuracy: 0.6538
# Epoch 11/20
# 160/160 [==============================] - 56s 351ms/step - loss: 36.9232 - accuracy: 0.9986 - val_loss: 36.7181 - val_accuracy: 0.6538
# Epoch 12/20
# 160/160 [==============================] - 56s 351ms/step - loss: 33.4964 - accuracy: 0.9965 - val_loss: 33.6137 - val_accuracy: 0.6731
# Epoch 13/20
# 160/160 [==============================] - 56s 351ms/step - loss: 30.5349 - accuracy: 0.9998 - val_loss: 30.8505 - val_accuracy: 0.6667
# Epoch 14/20
# 160/160 [==============================] - 56s 351ms/step - loss: 27.9704 - accuracy: 1.0000 - val_loss: 28.4275 - val_accuracy: 0.6603
# Epoch 15/20
# 160/160 [==============================] - 56s 351ms/step - loss: 25.7267 - accuracy: 1.0000 - val_loss: 26.3662 - val_accuracy: 0.6667
# Epoch 16/20
# 160/160 [==============================] - 56s 351ms/step - loss: 23.7498 - accuracy: 1.0000 - val_loss: 24.5589 - val_accuracy: 0.6474
# Epoch 17/20
# 160/160 [==============================] - 56s 352ms/step - loss: 22.0136 - accuracy: 0.9947 - val_loss: 22.5815 - val_accuracy: 0.6667
# Epoch 18/20
# 160/160 [==============================] - 56s 351ms/step - loss: 20.4594 - accuracy: 0.9994 - val_loss: 21.4933 - val_accuracy: 0.6154
# Epoch 19/20
# 160/160 [==============================] - 56s 351ms/step - loss: 19.0623 - accuracy: 1.0000 - val_loss: 20.3177 - val_accuracy: 0.6346
# Epoch 20/20
# 160/160 [==============================] - 56s 351ms/step - loss: 17.7959 - accuracy: 1.0000 - val_loss: 19.0921 - val_accuracy: 0.6731

# %%
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.ylim([0.5,1.1])
plt.show()

# %%
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
#plt.ylim([0.5,1.1])
plt.show()

# %%
y_predd = model.predict(X_test)
y_pred = (y_predd>0.5).astype(int)

# Plotting the confusing matrix
mat = confusion_matrix(y_test, y_pred.round())
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label')
print('accuracy: ' , accuracy_score(y_test, y_pred.round()).round(2))
print('recall: ' , recall_score(y_test, y_pred.round()).round(2))
print('precision: ' , precision_score(y_test, y_pred.round()).round(2))
